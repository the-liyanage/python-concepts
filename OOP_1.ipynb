# %%
name = input("Name: ")
house = input("House: ")
print(f"{name} from {house}")
# Out:
# Name:  hiruni
# House:  slytherin
# hiruni  from slytherin

# %% [markdown]
# ### Using two functions to get the output here

# %%
def main():
    name = get_name()
    house = get_house()
    print(f"{name} from {house}")

def get_name():
    return input("Name: ")

def get_house():
    return input("House: ")

if __name__ == "__main__":
    main()

# %% [markdown]
# ### Optimizing the two functions into one function

# %%
def main():
    student = get_student()
    print(f"{name} from {house}")
    


def get_student():
    name = input("Name: ")
    house = input("House: ")
    
    #We are actually returning a tuple with two values inside here 
    return (name, house)

if __name__ == "__main__":
    main()
# Out:
# Name:  hi
# House:  hi
# hiruni  from slytherin

# %% [markdown]
# ### Indexing the tuple to get the values

# %%
def main():
    student = get_student()
    print(f"{student[0]} from {student[1]}")

def get_student():
    name = input("Name: ")
    house = input("House: ")
    return (name,house)

if __name__ == "__main__":
    main()

# %% [markdown]
# ### The Immutability of Tuples (Here)

# %%
def main():
    student = get_student()
    if student[0]=="Padma":
        student[1] = "Ravenclaw"
    print(f"{student[0]} from {student[1]}") 

def get_student():
    name = input("Name: ")
    house = input("House: ")
    return (name, house)

if __name__ == "__main__":
    main()


#In here, we can see that tuples are "immutable"
# Out:
# Name:  Padma
# House:  h
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 13
#      10     return (name, house)
#      12 if __name__ == "__main__":
# ---> 13     main()
#
# Cell In[11], line 4, in main()
#       2 student = get_student()
#       3 if student[0]=="Padma":
# ----> 4     student[1] = "Ravenclaw"
#       5 print(f"{student[0]} from {student[1]}")
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### Optimizing by using a list (Mutable Ability)

# %%
#To eliminate this we can use a list as the return value here

def main():
    student = get_student()
    if student[0] == "Padma":
        student[1] = "Ravelclaw"
    print(f"{student[0]} from {student[1]}")    

def get_student():
    name = input("Name: ")
    house = input("House: ")

    #Returning the values as a list
    return [name, house]

if __name__ == "__main__":
    main()

# %% [markdown]
# ### Optimizing by using a Dictionary

# %%
#Even better way to represent the return values woould be choosing dictionaries (you don't necessary have to rememeber the number of indexes)

def main():
    student = get_student()
    print(f"{student['name']} from {student['house']}")

def get_student():
    #Dictionary
    student = {}
    student["name"] = input("Name: ")
    student["house"]  = input("House: ")
    return student

if __name__ == "__main__":
    main()
# Out:
# Name:  hiki
# House:  k
# hiki from k

# %%
def main():
    student = get_student()
    print(f"{student['name']} from {student['house']}")

def get_student():
    name = input("Name: ")
    house = input("House: ")
    return {"name": name, "house":house}

if __name__ =="__main__":
    main()

# %%
def main():
    student = get_student()
    if student['name'] == 'Padma':
        student['house'] = 'Ravenclaw'
    print(f"{student['name']} from {student['house']}")

def get_student():
    name = input("Name: ")
    house = input ("House: ")
    return {"name": name, "house": house}

if __name__ == "__main__":
    main()

# %% [markdown]
# ### Object Oriented Programming Starts Here

# %% [markdown]
# #### 1. Creating Attributes

# %%
#Declare a class

class Student():
    ...

def main():
    student = get_student()
    print(f"{student.name} from {student.house}")

def get_student():
    student = Student() #This is the object from the class Student()/ also knows as instance of a class

    #These are called attributes/instance variables of the class
    student.name = input("Name: ")
    student.house = input("House: ")
    return student

if __name__ == "__main__":
    main()

# %% [markdown]
# #### 2. Introducing Constructor method

# %%
class Student():
    ...

def main():
    student = get_student():
    print(f"{student.name} from {student.house}")

def get_student():
    #Creating an object/ Instance of class
    student = Student()
    name = input("Name: ")
    house = input("House: ")
    #Constructor method (we have passed two arguments to this function here) 
    #It is going to construct a student object for us
    student = Student(name, house)
    return student

if __name__ == "__main__":
    main()

# %% [markdown]
# #### 3. Introducing the `__init__` method

# %%
class Student():
    #Initialize the contents of an object from a class/ we are defining this method
    def __init__(self,name,house):
        self.name = name
        #self.n = name
        self.house = house
        #self.h = house

def main():
    student = get_student()
    print(f"{student.name} from {student.house}")


def get_student():
    name = input("Name: ")
    house = input("House: ")
    student = Student(name, house)
    return student

if __name__ == "__main__":
    main()

# %% [markdown]
# #### 3.1 Raising a Custom Error Expression

# %%
class Student():
    def __init__(self,name,house):
        #You can raise a Custom Error Expression here (Validating the attributes) 
        if not name:
            raise ValueError("Missing name")
        if house not in ["Gryffindor", "Hufflepuff", "Ravenclaw", "Slytherin"]:
            raise ValueError("Invalid Error")
        self.name = name
        self.house = house

def main():
    student = get_student()
    print(f"{student.name} from {student.house}")

def get_student():
    name = input("Name: ")
    house = input("House: ")
    return Student(name,house)
    

if __name__ == "__main__":
    main()

# %% [markdown]
# #### 4. Introducing `__str__` method

# %%
class Student():
    def __init__(self,name,house):
        if not name:
            raise ValueError("Missing Name")
        if house not in ["Gryffindor", "Hufflepuff", "Ravenclaw", "Slytherin"]:
            raise ValueError("Invalid Error")
        self.name = name
        self.house = house

    def __str__(self):
        return f"{self.name} from {self.house}"

def main():
    student = get_student()
    print(student)

def get_student():
    name = input("Name: ")
    house = input("House: ")
    #creates a student object
    return Student(name,house)

if __name__ == "__main__":
    main()
# Out:
#   Cell In[15], line 6
#     raise ValueError("Invalid Error"
#                     ^
# SyntaxError: '(' was never closed

# %% [markdown]
# #### 5. Introducing Methods(Behaviours)

# %%
class Student():
    def __init__(self,name,house,charm):
        if not name:
            raise ValueError("Missing name")
        if house not in ["Gryffindor", "Hufflepuff", "Ravenclaw", "Slytherin"]:
            raise ValueError("Invalid Error")
        self.name = name
        self.house = house

    def __str__(self):
        return f"{self.name} from {self.house}"

    def charm(self):
        #Matching the charms with the emojis
        match self.charm:
            case "Stag":
                return "🦄"
            case "Otter":
                return "🦦"
            case "Jack":
                return "🐙"
            #Giving a default value
            case _:
                return "🍄"


def main():
    student = get_student()
    print("Expecto Patronum!")
    print(student.charm())

def get_student():
    name = input("Name: ")
    house = input("House: ")
    charm = input("Patronus: ")
    return Student(name,house,charm)

if __name__ == "__main__":
    main()

# %% [markdown]
# #### 5. Introducting the Getter and Setter

# %% [markdown]
# - To prevent overwriting the attributes(values) -----> This will generate a ValueError

# %%
class Student():
    def __init__(self,name,house):
        if not name:
            raise ValueError("Missing Values")
        self.name = name
        self.house = house

    def __str__(self):
        return f"{self.name} from {self.house}"

    #Getter
    #Function for a class that gets some attribute

    @property 
    def house(self):
        return self._house

    #Setter
    #Fucntion in some class that sets some value
    
    @house.setter
    def house(self,house):
        if house not in ["Gryffindor", "Hufflepuff", "Ravenclaw", "Slytherin"]:
            raise ValueError("Invalid House")
        self._house = house


def main():
    student = get_student()
    student.house = "New Drive"
    print(student)

def get_student():
    name = input("Name: ")
    house = input("House: ")
    return Student(name,house)

if __name__ == "__main__":
    main()

# %%
class Student():
    def __init__(self,name,house):
        if not name:
            raise ValueError("Missing Value")
        self.name = name
        self.house = house

    def __str__(self):
        return f"{self.name} from {self.house}"

    @property
    def house(self):
        return self._house

    @house.setter
    def house(self,house):
        if house not in ["Gryffindor", "Hufflepuff", "Ravenclaw", "Slytherin"]:
            raise ValueError("Invalid Error")
        self._house = house    


def main():
    student = get_student()
    print(student)

def get_student():
    name = input("Name: ")
    house = input("House: ")
    return Student(name,house)

if __name__ == "__main__":
    main()

# %% [markdown]
# #### 5.1 Optimizing it further

# %%
class Student():
    def __init__(self,name,house):
        self.name = name
        self.house = house

    def __str__(self):
        return f"{self.name} from {self.house}"

    @property
    def name(self):
        return self._name

    @name.setter
    def name(self,name):
        if not name:
            raise ValueError("Missing Name")
        self._name

    @property
    def house(self):
        return self._house

    @house.setter
    def house(self,house):
        if house not in ["Gryffindor", "Hufflepuff", "Ravenclaw", "Slytherin"]:
            raise ValueError("Invalid House")
        self._house                    
                             


def main():
    student = get_student()
    print(student)

def get_student():
    name = input("Name: ")
    house = input("House: ")
    return Student(name,house)

if __name__ == "__main__":
    main()

# %% [markdown]
# #### 6. Introducting Class Method

# %%
import random

class Hat():
    def __init__(self):
        self.houses = ["Gryffindor", "Hufflepuff", "Ravenclaw", "Slytherin"]

    def sort(self,name):
        print(name, "is in", random.choice(self.houses))
        

hat = Hat()
hat.sort("Harry")
# Out:
# Harry is in Gryffindor

# %%
class Hat:
    #Introducing Class variables
    houses = ["Gryffindor", "Hufflepuff", "Ravenclaw", "Slytherin"]

    @classmethod
    def sort(cls,name):
        print(name, "is in", random.choice(cls.houses))

Hat.sort("Draco")
# Out:
# Draco is in Slytherin

# %%
class Student():
    def __init__(self,name,house):
        self.name = name
        self.house = house

    def __str__(self):
        return (f"{self.name} from {self.house}")

    @classmethod
    def get(cls):
        name = input("Name: ")
        house = input("House: ")
        return cls(name,house)


def main():
    student = Student.get()
    print(student)

if __name__ == "__main__":
    main()
# Out:
# Name:  Hiruni
# House:  sl
# Hiruni from sl

# %% [markdown]
# #### 7. Inheritance

# %%
class Student():
    def __init__(self,name,house):
        if not name:
            raise ValueError("Missing Name")
        self.name = name
        self.house = house

    ...

class Professor():
    def __init__(self,name,subject):
        if not name:
            raise ValueError("Missing Name")
        self.name = name
        self.house = house


#This 'method' looks bit redundant having to write the same type of code again and again

# %%
#Optimizing this 

class Wizards():
    def __init__(self,name):
        if not name:
            raise ValueError("Missing Name")
        self.name = name
    ...

class Student(Wizards):
    def __init__(self,name,house):
        super().__init__(name)
        self.house = house 

class Professor(Wizards):
    def __init__(self,name,subject):
        super().__init__(name)
        self.subject = subject


wizard = Wizards("Albus")
student = Student("Draco", "Sytherin")
professor = Professor("Snape", "Dark Arts")

# %% [markdown]
# #### 8. Operator Overloading

# %%
class Vault():
    def __init__(self, galleons =0, sickles = 0, knuts = 0):
        self.galleons = galleons
        self.sickles = sickles
        self.knuts = knuts

    def __str__(self):
        return f"{self.galleons} galleons, {self.sickles} sickles, {self.knuts} knuts"

potter = Vault(100, 25, 50)
print(potter)

weasley = Vault(50,50,25)
print(weasley)

galleons = potter.galleons + weasley.galleons
sickles = potter.sickles + weasley.sickles
knuts = potter.knuts + weasley.knuts

total = Vault(galleons, sickles, knuts)
print(total)
# Out:
# 100 galleons, 25 sickles, 50 knuts
# 50 galleons, 50 sickles, 25 knuts
# 150 galleons, 75 sickles, 75 knuts

# %%
class Vault():
    def __init__(self,galleons = 0, sickles = 0, knuts = 0):
        self.galleons = galleons
        self.sickles = sickles
        self.knuts = knuts

    def __str__(self):
        return f"{self.galleons} galleons, {self.sickles} sickels, {self.knuts} knuts"

    def __add__(self,other):
        galleons = self.galleons + other.galleons
        sickles = self.sickles + other.sickles
        knuts = self.knuts + other.knuts
        return f"{galleons} galleons,  {sickles} sickles, {knuts} knuts"

potter = Vault(100,25,50)
print(potter)

weasley = Vault(50,50,25)
print(weasley)

total = potter + weasley
print(total)
# Out:
# 100 galleons, 25 sickels, 50 knuts
# 50 galleons, 50 sickels, 25 knuts
# 150 galleons,  75 sickles, 75 knuts
