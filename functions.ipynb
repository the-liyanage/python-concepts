# %%
print("hello, hello?")
# Out:
# hello, hello?

# %%
name = input("What's your name?")
print("hi,")
print(name)
# Out:
# What's your name? liyanage
# hi,
# liyanage

# %%
#Over-writing the print function

name = input("What's your name?")
print("hi,", end="")
print(name)
# Out:
# What's your name? liyanage
# hi,liyanage

# %%
#Over-writing the print function(2.0)

name = input("What's your name?")
#positional parameters(name)          named parameters(sep,end)
print("hi,", name, sep="??")
# Out:
# What's your name? liyanage
# hi,??liyanage

# %%
name = input("what's your name?")

name = name.title()
print(f"{name}")
# Out:
# what's your name? HirUNI LIYANage
# Hiruni Liyanage

# %%
name = input("What's your name?").strip().title()

print(f"{name}")
# Out:
# What's your name? hiruni LIyanAGe
# Hiruni Liyanage
